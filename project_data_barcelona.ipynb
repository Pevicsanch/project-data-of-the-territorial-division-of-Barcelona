# %% [markdown]
# # Extracting data from the Barcelona City Hall open data website
# ______
#
# Here we are going to extract data from the [Barcelona City Hall Open Data Service](https://opendata-ajuntament.barcelona.cat/data/ca/dataset/divter/resource/ed515bb8-502b-4dff-96dc-769f72767919#additional-info) (this data is open and accessible to any user). Specifically, we are going to collect data on **socioeconomic indicators of the territorial division of the city of Barcelona**.
#
# This information will be stored in a dataframe.
#
# As we will see, the data obtained are URLs that we will later use to download pdf files.
#
# $~$

# %% [markdown]
# libraries we will use:

# %%
import requests
import pandas as pd
import numpy as np
import re
import os
import pprint
import pdfplumber

from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ____

# %% [markdown]
# ## Scraping the city hall website
#
# It is true that the city council's website allows us open access to the data, but we could automate this.
#
# <img src="./images/web_image2.png" width="500" height="340"/>
#
#
# $~$
#
# as we can see in the image above, the first thing we would have to do is download one or one of the csv files where we will find a series of URLs that we will then use to download the pdf files.
#
# $~$

# %%
#url we want to scrape
url = "https://opendata-ajuntament.barcelona.cat/data/ca/dataset/divter"

#request the url 
web = requests.get(url)
#init soup 
soup = BeautifulSoup(web.content,"html.parser")

# %%
# find all the links in the page (div class="resource-actions-small">)
links = soup.find_all("div", class_="resource-actions-small")


links = [link.find("a") for link in links]

# get the links
links = [link.get("href") for link in links]

# %% [markdown]
# in the links list we have each one of the links that will allow us to download the csv files. let's create a dataframe with this information

# %%
#create a dataframe with the links
links = pd.DataFrame(links, columns=["link"])

# %%
#save the dataframe in a csv file as a backup 
links.to_csv("links.csv", index=False)

# %%
# read links.csv
links = pd.read_csv("links.csv")

# %%
links.head()
# Out:
#                                                 link
# 0  https://opendata-ajuntament.barcelona.cat/data...
# 1  https://opendata-ajuntament.barcelona.cat/data...
# 2  https://opendata-ajuntament.barcelona.cat/data...
# 3  https://opendata-ajuntament.barcelona.cat/data...
# 4  https://opendata-ajuntament.barcelona.cat/data...

# %% [markdown]
# _____

# %% [markdown]
# ## Download and save files with a url
#
# We can use the dataframe "links" with the urls to download each of the .csv files. Note that each of the files refers to a specific year. The next cell will create a folder "csv_folder" where we will save the .cvs files.

# %%
#access the links, save the csv files in a folder called "csv_files"
#create a folder called "csv_files" if it doesn't exist
if not os.path.exists("csv_files"):
      os.mkdir("csv_files")

#loop through the links
for link in links["link"]:
      file_name = link.split("/")[-1]
      file_name = file_name.split("?")[0]
      file_name = file_name.split(".")[0]
      file_name = file_name + ".csv"
      print(file_name)
      with open(os.path.join("csv_files", file_name), "wb") as f:
         f.write(requests.get(link).content)
# Out:
# 2019_divter.csv
# 2018_divter.csv
# 2017_divter.csv
# 2016_divter.csv
# 2015_divter.csv
# 2014_divter.csv
# 2013_divter.csv
# 2012_divter.csv
# 2011_divter.csv
# 2010_divter.csv
# 2009_divter.csv
# 2008_divter.csv

# %% [markdown]
# We open one of the files we have downloaded to copy the columns

# %%
#open one of the csv files 
df = pd.read_csv("csv_files/2019_divter.csv")

#check the columns names
print("the columns names are: ", df.columns)
# Out:
# the columns names are:  Index(['CODI_DIVISIO_TERRITORIAL', 'NOM_DIVISIO_TERRITORIAL',
#        'CATEGORIA_DIVISIO', 'CODI_DIVISIO_TERRITORIAL_PARE',
#        'URL_FITXA_DIVISIO_TERRITORIAL'],
#       dtype='object')

# %% [markdown]
# let's create a new column any that will be used to know what year the information is from

# %%
#create a list with the columns names and add the column "Any"
columns = list(df.columns)
columns.append("Any")

#create a new dataframe with the columns names
df_new = pd.DataFrame(columns=columns)

#put the column "any" in the first position
df_new = df_new[["Any"] + df_new.columns[:-1].tolist()]

# %%
df_new
# Out:
# Empty DataFrame
# Columns: [Any, CODI_DIVISIO_TERRITORIAL, NOM_DIVISIO_TERRITORIAL, CATEGORIA_DIVISIO, CODI_DIVISIO_TERRITORIAL_PARE, URL_FITXA_DIVISIO_TERRITORIAL]
# Index: []

# %% [markdown]
# this empty dataframe will be used to fill it with the information that we are going to obtain from each of the csv files.

# %%
#loop through the csv files
for file in os.listdir("csv_files"):
      #read the csv file
      df = pd.read_csv(os.path.join("csv_files", file))
      #get the year from the file name ""
      year = file.split("_")[0]
      #add the year to the dataframe in the column "Any"
      df["Any"] = year
      #concatenate the dataframes
      df_new = pd.concat([df_new, df], axis=0)

# %%
#show the first 5 rows of the dataframe
df_new.head()
# Out:
#     Any CODI_DIVISIO_TERRITORIAL                NOM_DIVISIO_TERRITORIAL  \
# 0  2017                     B-01                               el Raval
# 1  2017                     B-02                         el Barri Gòtic
# 2  2017                     B-03                         la Barceloneta
# 3  2017                     B-04  Sant Pere, Santa Caterina i la Ribera
# 4  2017                     B-05                          el Fort Pienc
#
#   CATEGORIA_DIVISIO CODI_DIVISIO_TERRITORIAL_PARE  \
# 0             Barri                          D-01
# 1             Barri                          D-01
# 2             Barri                          D-01
# 3             Barri                          D-01
# 4             Barri                          D-02
#
#                        URL_FITXA_DIVISIO_TERRITORIAL
# 0  http://www.bcn.cat/estadistica/catala/dades/in...
# 1  http://www.bcn.cat/estadistica/catala/dades/in...
# 2  http://www.bcn.cat/estadistica/catala/dades/in...
# 3  http://www.bcn.cat/estadistica/catala/dades/in...
# 4  http://www.bcn.cat/estadistica/catala/dades/in...

# %% [markdown]
# Now we have a dataframe with the columns:
# + Any = is the year of information
# + CODI_DIVISIO_TERRITORIAL: is the code of the territorial division managed by the city council of Barcelona for each of the neighborhoods.
# + NOM_DIVISIO_TERRITORIAL = this is the name of each of the barcelona neighborhoods.
# + CATEGORY_DIVISION = here there can be either (Barri) Neighborhood or District (Districte),
# + CODI_DIVISIO_TERRITORIAL_PARE = this code is internal to the City Council of Barcelona.
#
# + URL_FITXA_DIVISIO_TERRITORIAL = this is the url from where we can download the pdf with the specific information of the neighborhood and the year.
#
# Knowing this, we are only interested in the rows where we have url address, the following cells are useful for this purpose

# %%
#show if there are null values in the URL_FITXA_DIVISIO_TERRITORIAL
print("there are null values in the URL_FITXA_DIVISIO_TERRITORIAL: ", df_new["URL_FITXA_DIVISIO_TERRITORIAL"].isnull().values.any())
print("the number of null values in the URL_FITXA_DIVISIO_TERRITORIAL: ", df_new["URL_FITXA_DIVISIO_TERRITORIAL"].isnull().sum())

#show if there are empty values in the URL_FITXA_DIVISIO_TERRITORIAL
print("there are empty values in the URL_FITXA_DIVISIO_TERRITORIAL: ", df_new["URL_FITXA_DIVISIO_TERRITORIAL"].eq("").values.any())
print("the number of empty values in the URL_FITXA_DIVISIO_TERRITORIAL: ", df_new["URL_FITXA_DIVISIO_TERRITORIAL"].eq("").sum())
# Out:
# there are null values in the URL_FITXA_DIVISIO_TERRITORIAL:  True
# the number of null values in the URL_FITXA_DIVISIO_TERRITORIAL:  120
# there are empty values in the URL_FITXA_DIVISIO_TERRITORIAL:  False
# the number of empty values in the URL_FITXA_DIVISIO_TERRITORIAL:  0

# %%
#drop the rows with null values in the URL_FITXA_DIVISIO_TERRITORIAL
df_new = df_new.dropna(subset=["URL_FITXA_DIVISIO_TERRITORIAL"])

# %%
#save the dataframe in a csv file
df_new.to_csv("project_data_barcelona.csv", index=False)

# %%
#read the csv file
df_new = pd.read_csv("project_data_barcelona.csv")

# %% [markdown]
# _____

# %% [markdown]
# ## Downloading pdf files
#
# Before we have obtained the URLs that will be used to download the .pdf files, now we are going to download them and save them in a folder that we are going to create and call pdf_files.
#
# $~$
#
# One of the problems with the city council's website is that the URLs they offer are corrupted. We have previously noticed this. The correct URLs are the ones we have called "url_base". The first thing we are going to do is to change the corrupted URLs for the correct ones.

# %%
# we previous know that the proper url to access the pdf files is the url in the column "URL_FITXA_DIVISIO_TERRITORIAL" have the following structure:

url_base = "https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes"

#we also previous know that the wrong url to access the pdf files is the url in the column "URL_FITXA_DIVISIO_TERRITORIAL" have the following structure:
url_wrong ="http://www.bcn.cat/estadistica/catala/dades/inf/barris"

#find the values in the column "URL_FITXA_DIVISIO_TERRITORIAL" that have the url_base
df_new["URL_FITXA_DIVISIO_TERRITORIAL"].str.contains(url_base).value_counts()
# Out:
# False    803
# True      73
# Name: URL_FITXA_DIVISIO_TERRITORIAL, dtype: int64

# %%
# for the values that have the url_wrong, we replace the url_wrong with the url_base
df_new.loc[df_new["URL_FITXA_DIVISIO_TERRITORIAL"].str.contains(url_wrong), "URL_FITXA_DIVISIO_TERRITORIAL"] = df_new.loc[df_new["URL_FITXA_DIVISIO_TERRITORIAL"].str.contains(
    url_wrong), "URL_FITXA_DIVISIO_TERRITORIAL"].str.replace(url_wrong, url_base)

# %%
#save the dataframe in a csv file for backup.
df_new.to_csv("project_data_barcelona_url_clean.csv", index=False)

# %%
#read the csv file
df = pd.read_csv("project_data_barcelona_url_clean.csv")

# %% [markdown]
# _____

# %% [markdown]
# $~$
#
# Now, with the correct URl we can download the information. The next cell is used to create a folder "pdf_files", and download the files and save them in that folder. In addition we are going to call each of the files by the year to which the information refers and the name of the neighborhood, that is to say, it will have the following structure:
#
# *year_neighborhood name.pdf*

# %%
#create a folder to save the pdf files called "pdf_files"
#check if the folder exists and if not create it
import time
import urllib.request
errors = []
if not os.path.exists("pdf_files"):
    os.mkdir("pdf_files")

#loop through the dataframe and download the pdf files
for i in range(len(df)):
    #get the url of the pdf file
    url = df["URL_FITXA_DIVISIO_TERRITORIAL"][i]
    #get the name of the file Any+NOM_DIVISIO+.pdf
    file_name = str(df["Any"][i]) + "_" + df["NOM_DIVISIO_TERRITORIAL"][i] + ".pdf"
    #create the path to save the file
    path = os.path.join("pdf_files", file_name)
    #try to download the file in files and save them in the folder pdf_files if the download fails print the error, the url and the file name. save the error with the name of the file in a list
    try:
        urllib.request.urlretrieve(url, path)
        #print the name of the file downloaded

    except Exception as e:
        print(e)
        print(url)
        print(file_name)
        errors.append(file_name)
    #wait 1 second to avoid the error 429
    # time.sleep(1)
# Out:
# 2017_el Raval.pdf
# 2017_el Barri Gòtic.pdf
# 2017_la Barceloneta.pdf
# 2017_Sant Pere, Santa Caterina i la Ribera.pdf
# 2017_el Fort Pienc.pdf
# 2017_la Sagrada Família.pdf
# 2017_la Dreta de l'Eixample.pdf
# 2017_l'Antiga Esquerra de l'Eixample.pdf
# 2017_la Nova Esquerra de l'Eixample.pdf
# 2017_Sant Antoni.pdf
# 2017_el Poble-sec.pdf
# 2017_la Marina del Prat Vermell.pdf
# 2017_la Marina de Port.pdf
# 2017_la Font de la Guatlla.pdf
# 2017_Hostafrancs.pdf
# 2017_la Bordeta.pdf
# 2017_Sants - Badal.pdf
# 2017_Sants.pdf
# 2017_les Corts.pdf
# 2017_la Maternitat i Sant Ramon.pdf
# 2017_Pedralbes.pdf
# 2017_Vallvidrera, el Tibidabo i les Planes.pdf
# 2017_Sarrià.pdf
# 2017_les Tres Torres.pdf
# 2017_Sant Gervasi - la Bonanova.pdf
# 2017_Sant Gervasi - Galvany.pdf
# 2017_el Putxet i el Farró.pdf
# 2017_Vallcarca i els Penitents.pdf
# 2017_el Coll.pdf
# 2017_la Salut.pdf
# 2017_la Vila de Gràcia.pdf
# 2017_el Camp d'en Grassot i Gràcia Nova.pdf
# 2017_el Baix Guinardó.pdf
# 2017_Can Baró.pdf
# 2017_el Guinardó.pdf
# 2017_la Font d'en Fargues.pdf
# 2017_el Carmel.pdf
# 2017_la Teixonera.pdf
# 2017_Sant Genís dels Agudells.pdf
# 2017_Montbau.pdf
# 2017_la Vall d'Hebron.pdf
# 2017_la Clota.pdf
# 2017_Horta.pdf
# 2017_Vilapicina i la Torre Llobeta.pdf
# 2017_Porta.pdf
# 2017_el Turó de la Peira.pdf
# 2017_Can Peguera.pdf
# 2017_la Guineueta.pdf
# 2017_Canyelles.pdf
# 2017_les Roquetes.pdf
# 2017_Verdun.pdf
# 2017_la Prosperitat.pdf
# 2017_la Trinitat Nova.pdf
# 2017_Torre Baró.pdf
# 2017_Ciutat Meridiana.pdf
# 2017_Vallbona.pdf
# 2017_la Trinitat Vella.pdf
# 2017_Baró de Viver.pdf
# 2017_el Bon Pastor.pdf
# 2017_Sant Andreu.pdf
# 2017_la Sagrera.pdf
# 2017_el Congrés i els Indians.pdf
# 2017_Navas.pdf
# 2017_el Camp de l'Arpa del Clot.pdf
# 2017_el Clot.pdf
# 2017_el Parc i la Llacuna del Poblenou.pdf
# 2017_la Vila Olímpica del Poblenou.pdf
# 2017_el Poblenou.pdf
# 2017_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2017_el Besòs i el Maresme.pdf
# 2017_Provençals del Poblenou.pdf
# 2017_Sant Martí de Provençals.pdf
# 2017_la Verneda i la Pau.pdf
# 2012_el Raval.pdf
# 2012_el Barri Gòtic.pdf
# 2012_la Barceloneta.pdf
# 2012_Sant Pere, Santa Caterina i la Ribera.pdf
# 2012_el Fort Pienc.pdf
# 2012_la Sagrada Família.pdf
# 2012_la Dreta de l'Eixample.pdf
# 2012_l'Antiga Esquerra de l'Eixample.pdf
# 2012_la Nova Esquerra de l'Eixample.pdf
# 2012_Sant Antoni.pdf
# 2012_el Poble-sec.pdf
# 2012_la Marina del Prat Vermell.pdf
# 2012_la Marina de Port.pdf
# 2012_la Font de la Guatlla.pdf
# 2012_Hostafrancs.pdf
# 2012_la Bordeta.pdf
# 2012_Sants - Badal.pdf
# 2012_Sants.pdf
# 2012_les Corts.pdf
# 2012_la Maternitat i Sant Ramon.pdf
# 2012_Pedralbes.pdf
# 2012_Vallvidrera, el Tibidabo i les Planes.pdf
# 2012_Sarrià.pdf
# 2012_les Tres Torres.pdf
# 2012_Sant Gervasi - la Bonanova.pdf
# 2012_Sant Gervasi - Galvany.pdf
# 2012_el Putxet i el Farró.pdf
# 2012_Vallcarca i els Penitents.pdf
# 2012_el Coll.pdf
# 2012_la Salut.pdf
# 2012_la Vila de Gràcia.pdf
# 2012_el Camp d'en Grassot i Gràcia Nova.pdf
# 2012_el Baix Guinardó.pdf
# 2012_Can Baró.pdf
# 2012_el Guinardó.pdf
# 2012_la Font d'en Fargues.pdf
# 2012_el Carmel.pdf
# 2012_la Teixonera.pdf
# 2012_Sant Genís dels Agudells.pdf
# 2012_Montbau.pdf
# 2012_la Vall d'Hebron.pdf
# 2012_la Clota.pdf
# 2012_Horta.pdf
# 2012_Vilapicina i la Torre Llobeta.pdf
# 2012_Porta.pdf
# 2012_el Turó de la Peira.pdf
# 2012_Can Peguera.pdf
# 2012_la Guineueta.pdf
# 2012_Canyelles.pdf
# 2012_les Roquetes.pdf
# 2012_Verdun.pdf
# 2012_la Prosperitat.pdf
# 2012_la Trinitat Nova.pdf
# 2012_Torre Baró.pdf
# 2012_Ciutat Meridiana.pdf
# 2012_Vallbona.pdf
# 2012_la Trinitat Vella.pdf
# 2012_Baró de Viver.pdf
# 2012_el Bon Pastor.pdf
# 2012_Sant Andreu.pdf
# 2012_la Sagrera.pdf
# 2012_el Congrés i els Indians.pdf
# 2012_Navas.pdf
# 2012_el Camp de l'Arpa del Clot.pdf
# 2012_el Clot.pdf
# 2012_el Parc i la Llacuna del Poblenou.pdf
# 2012_la Vila Olímpica del Poblenou.pdf
# 2012_el Poblenou.pdf
# 2012_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2012_el Besòs i el Maresme.pdf
# 2012_Provençals del Poblenou.pdf
# 2012_Sant Martí de Provençals.pdf
# 2012_la Verneda i la Pau.pdf
# 2009_el Raval.pdf
# 2009_el Barri Gòtic.pdf
# 2009_la Barceloneta.pdf
# 2009_Sant Pere, Santa Caterina i la Ribera.pdf
# 2009_el Fort Pienc.pdf
# 2009_la Sagrada Família.pdf
# 2009_la Dreta de l'Eixample.pdf
# 2009_l'Antiga Esquerra de l'Eixample.pdf
# 2009_la Nova Esquerra de l'Eixample.pdf
# 2009_Sant Antoni.pdf
# 2009_el Poble-sec.pdf
# 2009_la Marina del Prat Vermell.pdf
# 2009_la Marina de Port.pdf
# 2009_la Font de la Guatlla.pdf
# 2009_Hostafrancs.pdf
# 2009_la Bordeta.pdf
# 2009_Sants - Badal.pdf
# 2009_Sants.pdf
# 2009_les Corts.pdf
# 2009_la Maternitat i Sant Ramon.pdf
# 2009_Pedralbes.pdf
# 2009_Vallvidrera, el Tibidabo i les Planes.pdf
# 2009_Sarrià.pdf
# 2009_les Tres Torres.pdf
# 2009_Sant Gervasi - la Bonanova.pdf
# 2009_Sant Gervasi - Galvany.pdf
# 2009_el Putxet i el Farró.pdf
# 2009_Vallcarca i els Penitents.pdf
# 2009_el Coll.pdf
# 2009_la Salut.pdf
# 2009_la Vila de Gràcia.pdf
# 2009_el Camp d'en Grassot i Gràcia Nova.pdf
# 2009_el Baix Guinardó.pdf
# 2009_Can Baró.pdf
# 2009_el Guinardó.pdf
# 2009_la Font d'en Fargues.pdf
# 2009_el Carmel.pdf
# 2009_la Teixonera.pdf
# 2009_Sant Genís dels Agudells.pdf
# 2009_Montbau.pdf
# 2009_la Vall d'Hebron.pdf
# 2009_la Clota.pdf
# 2009_Horta.pdf
# 2009_Vilapicina i la Torre Llobeta.pdf
# 2009_Porta.pdf
# 2009_el Turó de la Peira.pdf
# 2009_Can Peguera.pdf
# 2009_la Guineueta.pdf
# 2009_Canyelles.pdf
# 2009_les Roquetes.pdf
# 2009_Verdun.pdf
# 2009_la Prosperitat.pdf
# 2009_la Trinitat Nova.pdf
# 2009_Torre Baró.pdf
# 2009_Ciutat Meridiana.pdf
# 2009_Vallbona.pdf
# 2009_la Trinitat Vella.pdf
# 2009_Baró de Viver.pdf
# 2009_el Bon Pastor.pdf
# 2009_Sant Andreu.pdf
# 2009_la Sagrera.pdf
# 2009_el Congrés i els Indians.pdf
# 2009_Navas.pdf
# 2009_el Camp de l'Arpa del Clot.pdf
# 2009_el Clot.pdf
# 2009_el Parc i la Llacuna del Poblenou.pdf
# 2009_la Vila Olímpica del Poblenou.pdf
# 2009_el Poblenou.pdf
# 2009_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2009_el Besòs i el Maresme.pdf
# 2009_Provençals del Poblenou.pdf
# 2009_Sant Martí de Provençals.pdf
# 2009_la Verneda i la Pau.pdf
# 2015_el Raval.pdf
# 2015_el Barri Gòtic.pdf
# 2015_la Barceloneta.pdf
# 2015_Sant Pere, Santa Caterina i la Ribera.pdf
# 2015_el Fort Pienc.pdf
# 2015_la Sagrada Família.pdf
# 2015_la Dreta de l'Eixample.pdf
# 2015_l'Antiga Esquerra de l'Eixample.pdf
# 2015_la Nova Esquerra de l'Eixample.pdf
# 2015_Sant Antoni.pdf
# 2015_el Poble-sec.pdf
# 2015_la Marina del Prat Vermell.pdf
# 2015_la Marina de Port.pdf
# 2015_la Font de la Guatlla.pdf
# 2015_Hostafrancs.pdf
# 2015_la Bordeta.pdf
# 2015_Sants - Badal.pdf
# 2015_Sants.pdf
# 2015_les Corts.pdf
# 2015_la Maternitat i Sant Ramon.pdf
# 2015_Pedralbes.pdf
# 2015_Vallvidrera, el Tibidabo i les Planes.pdf
# 2015_Sarrià.pdf
# 2015_les Tres Torres.pdf
# 2015_Sant Gervasi - la Bonanova.pdf
# 2015_Sant Gervasi - Galvany.pdf
# 2015_el Putxet i el Farró.pdf
# 2015_Vallcarca i els Penitents.pdf
# 2015_el Coll.pdf
# 2015_la Salut.pdf
# 2015_la Vila de Gràcia.pdf
# 2015_el Camp d'en Grassot i Gràcia Nova.pdf
# 2015_el Baix Guinardó.pdf
# 2015_Can Baró.pdf
# 2015_el Guinardó.pdf
# 2015_la Font d'en Fargues.pdf
# 2015_el Carmel.pdf
# 2015_la Teixonera.pdf
# 2015_Sant Genís dels Agudells.pdf
# 2015_Montbau.pdf
# 2015_la Vall d'Hebron.pdf
# 2015_la Clota.pdf
# 2015_Horta.pdf
# 2015_Vilapicina i la Torre Llobeta.pdf
# 2015_Porta.pdf
# 2015_el Turó de la Peira.pdf
# 2015_Can Peguera.pdf
# 2015_la Guineueta.pdf
# 2015_Canyelles.pdf
# 2015_les Roquetes.pdf
# 2015_Verdun.pdf
# 2015_la Prosperitat.pdf
# 2015_la Trinitat Nova.pdf
# 2015_Torre Baró.pdf
# 2015_Ciutat Meridiana.pdf
# 2015_Vallbona.pdf
# 2015_la Trinitat Vella.pdf
# 2015_Baró de Viver.pdf
# 2015_el Bon Pastor.pdf
# 2015_Sant Andreu.pdf
# 2015_la Sagrera.pdf
# 2015_el Congrés i els Indians.pdf
# 2015_Navas.pdf
# 2015_el Camp de l'Arpa del Clot.pdf
# 2015_el Clot.pdf
# 2015_el Parc i la Llacuna del Poblenou.pdf
# 2015_la Vila Olímpica del Poblenou.pdf
# 2015_el Poblenou.pdf
# 2015_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2015_el Besòs i el Maresme.pdf
# 2015_Provençals del Poblenou.pdf
# 2015_Sant Martí de Provençals.pdf
# 2015_la Verneda i la Pau.pdf
# 2018_el Raval.pdf
# 2018_el Barri Gòtic.pdf
# 2018_la Barceloneta.pdf
# 2018_Sant Pere, Santa Caterina i la Ribera.pdf
# 2018_el Fort Pienc.pdf
# 2018_la Sagrada Família.pdf
# 2018_la Dreta de l'Eixample.pdf
# 2018_l'Antiga Esquerra de l'Eixample.pdf
# 2018_la Nova Esquerra de l'Eixample.pdf
# 2018_Sant Antoni.pdf
# 2018_el Poble-sec.pdf
# 2018_la Marina del Prat Vermell.pdf
# 2018_la Marina de Port.pdf
# 2018_la Font de la Guatlla.pdf
# 2018_Hostafrancs.pdf
# 2018_la Bordeta.pdf
# 2018_Sants - Badal.pdf
# 2018_Sants.pdf
# 2018_les Corts.pdf
# 2018_la Maternitat i Sant Ramon.pdf
# 2018_Pedralbes.pdf
# 2018_Vallvidrera, el Tibidabo i les Planes.pdf
# 2018_Sarrià.pdf
# 2018_les Tres Torres.pdf
# 2018_Sant Gervasi - la Bonanova.pdf
# 2018_Sant Gervasi - Galvany.pdf
# 2018_el Putxet i el Farró.pdf
# 2018_Vallcarca i els Penitents.pdf
# 2018_el Coll.pdf
# 2018_la Salut.pdf
# 2018_la Vila de Gràcia.pdf
# 2018_el Camp d'en Grassot i Gràcia Nova.pdf
# 2018_el Baix Guinardó.pdf
# 2018_Can Baró.pdf
# 2018_el Guinardó.pdf
# 2018_la Font d'en Fargues.pdf
# 2018_el Carmel.pdf
# 2018_la Teixonera.pdf
# 2018_Sant Genís dels Agudells.pdf
# 2018_Montbau.pdf
# 2018_la Vall d'Hebron.pdf
# 2018_la Clota.pdf
# 2018_Horta.pdf
# 2018_Vilapicina i la Torre Llobeta.pdf
# 2018_Porta.pdf
# 2018_el Turó de la Peira.pdf
# 2018_Can Peguera.pdf
# 2018_la Guineueta.pdf
# 2018_Canyelles.pdf
# 2018_les Roquetes.pdf
# 2018_Verdun.pdf
# 2018_la Prosperitat.pdf
# 2018_la Trinitat Nova.pdf
# 2018_Torre Baró.pdf
# 2018_Ciutat Meridiana.pdf
# 2018_Vallbona.pdf
# 2018_la Trinitat Vella.pdf
# 2018_Baró de Viver.pdf
# 2018_el Bon Pastor.pdf
# 2018_Sant Andreu.pdf
# 2018_la Sagrera.pdf
# 2018_el Congrés i els Indians.pdf
# 2018_Navas.pdf
# 2018_el Camp de l'Arpa del Clot.pdf
# 2018_el Clot.pdf
# 2018_el Parc i la Llacuna del Poblenou.pdf
# 2018_la Vila Olímpica del Poblenou.pdf
# 2018_el Poblenou.pdf
# 2018_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2018_el Besòs i el Maresme.pdf
# 2018_Provençals del Poblenou.pdf
# 2018_Sant Martí de Provençals.pdf
# 2018_la Verneda i la Pau.pdf
# 2010_el Raval.pdf
# 2010_el Barri Gòtic.pdf
# 2010_la Barceloneta.pdf
# 2010_Sant Pere, Santa Caterina i la Ribera.pdf
# 2010_el Fort Pienc.pdf
# 2010_la Sagrada Família.pdf
# 2010_la Dreta de l'Eixample.pdf
# 2010_l'Antiga Esquerra de l'Eixample.pdf
# 2010_la Nova Esquerra de l'Eixample.pdf
# 2010_Sant Antoni.pdf
# 2010_el Poble-sec.pdf
# 2010_la Marina del Prat Vermell.pdf
# 2010_la Marina de Port.pdf
# 2010_la Font de la Guatlla.pdf
# 2010_Hostafrancs.pdf
# 2010_la Bordeta.pdf
# 2010_Sants - Badal.pdf
# 2010_Sants.pdf
# 2010_les Corts.pdf
# 2010_la Maternitat i Sant Ramon.pdf
# 2010_Pedralbes.pdf
# 2010_Vallvidrera, el Tibidabo i les Planes.pdf
# 2010_Sarrià.pdf
# 2010_les Tres Torres.pdf
# 2010_Sant Gervasi - la Bonanova.pdf
# 2010_Sant Gervasi - Galvany.pdf
# 2010_el Putxet i el Farró.pdf
# 2010_Vallcarca i els Penitents.pdf
# 2010_el Coll.pdf
# 2010_la Salut.pdf
# 2010_la Vila de Gràcia.pdf
# 2010_el Camp d'en Grassot i Gràcia Nova.pdf
# 2010_el Baix Guinardó.pdf
# 2010_Can Baró.pdf
# 2010_el Guinardó.pdf
# 2010_la Font d'en Fargues.pdf
# 2010_el Carmel.pdf
# 2010_la Teixonera.pdf
# 2010_Sant Genís dels Agudells.pdf
# 2010_Montbau.pdf
# 2010_la Vall d'Hebron.pdf
# 2010_la Clota.pdf
# 2010_Horta.pdf
# 2010_Vilapicina i la Torre Llobeta.pdf
# 2010_Porta.pdf
# 2010_el Turó de la Peira.pdf
# 2010_Can Peguera.pdf
# 2010_la Guineueta.pdf
# 2010_Canyelles.pdf
# 2010_les Roquetes.pdf
# 2010_Verdun.pdf
# 2010_la Prosperitat.pdf
# 2010_la Trinitat Nova.pdf
# 2010_Torre Baró.pdf
# 2010_Ciutat Meridiana.pdf
# 2010_Vallbona.pdf
# 2010_la Trinitat Vella.pdf
# 2010_Baró de Viver.pdf
# 2010_el Bon Pastor.pdf
# 2010_Sant Andreu.pdf
# 2010_la Sagrera.pdf
# 2010_el Congrés i els Indians.pdf
# 2010_Navas.pdf
# 2010_el Camp de l'Arpa del Clot.pdf
# 2010_el Clot.pdf
# 2010_el Parc i la Llacuna del Poblenou.pdf
# 2010_la Vila Olímpica del Poblenou.pdf
# 2010_el Poblenou.pdf
# 2010_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2010_el Besòs i el Maresme.pdf
# 2010_Provençals del Poblenou.pdf
# 2010_Sant Martí de Provençals.pdf
# 2010_la Verneda i la Pau.pdf
# 2013_el Raval.pdf
# 2013_el Barri Gòtic.pdf
# 2013_la Barceloneta.pdf
# 2013_Sant Pere, Santa Caterina i la Ribera.pdf
# 2013_el Fort Pienc.pdf
# 2013_la Sagrada Família.pdf
# 2013_la Dreta de l'Eixample.pdf
# 2013_l'Antiga Esquerra de l'Eixample.pdf
# 2013_la Nova Esquerra de l'Eixample.pdf
# 2013_Sant Antoni.pdf
# 2013_el Poble-sec.pdf
# 2013_la Marina del Prat Vermell.pdf
# 2013_la Marina de Port.pdf
# 2013_la Font de la Guatlla.pdf
# 2013_Hostafrancs.pdf
# 2013_la Bordeta.pdf
# 2013_Sants - Badal.pdf
# 2013_Sants.pdf
# 2013_les Corts.pdf
# 2013_la Maternitat i Sant Ramon.pdf
# 2013_Pedralbes.pdf
# 2013_Vallvidrera, el Tibidabo i les Planes.pdf
# 2013_Sarrià.pdf
# 2013_les Tres Torres.pdf
# 2013_Sant Gervasi - la Bonanova.pdf
# 2013_Sant Gervasi - Galvany.pdf
# 2013_el Putxet i el Farró.pdf
# 2013_Vallcarca i els Penitents.pdf
# 2013_el Coll.pdf
# 2013_la Salut.pdf
# 2013_la Vila de Gràcia.pdf
# 2013_el Camp d'en Grassot i Gràcia Nova.pdf
# 2013_el Baix Guinardó.pdf
# 2013_Can Baró.pdf
# 2013_el Guinardó.pdf
# 2013_la Font d'en Fargues.pdf
# 2013_el Carmel.pdf
# 2013_la Teixonera.pdf
# 2013_Sant Genís dels Agudells.pdf
# 2013_Montbau.pdf
# 2013_la Vall d'Hebron.pdf
# 2013_la Clota.pdf
# 2013_Horta.pdf
# 2013_Vilapicina i la Torre Llobeta.pdf
# 2013_Porta.pdf
# 2013_el Turó de la Peira.pdf
# 2013_Can Peguera.pdf
# 2013_la Guineueta.pdf
# 2013_Canyelles.pdf
# 2013_les Roquetes.pdf
# 2013_Verdun.pdf
# 2013_la Prosperitat.pdf
# 2013_la Trinitat Nova.pdf
# 2013_Torre Baró.pdf
# 2013_Ciutat Meridiana.pdf
# 2013_Vallbona.pdf
# 2013_la Trinitat Vella.pdf
# 2013_Baró de Viver.pdf
# 2013_el Bon Pastor.pdf
# 2013_Sant Andreu.pdf
# 2013_la Sagrera.pdf
# 2013_el Congrés i els Indians.pdf
# 2013_Navas.pdf
# 2013_el Camp de l'Arpa del Clot.pdf
# 2013_el Clot.pdf
# 2013_el Parc i la Llacuna del Poblenou.pdf
# 2013_la Vila Olímpica del Poblenou.pdf
# 2013_el Poblenou.pdf
# 2013_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2013_el Besòs i el Maresme.pdf
# 2013_Provençals del Poblenou.pdf
# 2013_Sant Martí de Provençals.pdf
# 2013_la Verneda i la Pau.pdf
# 2016_el Raval.pdf
# 2016_el Barri Gòtic.pdf
# 2016_la Barceloneta.pdf
# 2016_Sant Pere, Santa Caterina i la Ribera.pdf
# 2016_el Fort Pienc.pdf
# 2016_la Sagrada Família.pdf
# 2016_la Dreta de l'Eixample.pdf
# 2016_l'Antiga Esquerra de l'Eixample.pdf
# 2016_la Nova Esquerra de l'Eixample.pdf
# 2016_Sant Antoni.pdf
# 2016_el Poble-sec.pdf
# 2016_la Marina del Prat Vermell.pdf
# 2016_la Marina de Port.pdf
# 2016_la Font de la Guatlla.pdf
# 2016_Hostafrancs.pdf
# 2016_la Bordeta.pdf
# 2016_Sants - Badal.pdf
# 2016_Sants.pdf
# 2016_les Corts.pdf
# 2016_la Maternitat i Sant Ramon.pdf
# 2016_Pedralbes.pdf
# 2016_Vallvidrera, el Tibidabo i les Planes.pdf
# 2016_Sarrià.pdf
# 2016_les Tres Torres.pdf
# 2016_Sant Gervasi - la Bonanova.pdf
# 2016_Sant Gervasi - Galvany.pdf
# 2016_el Putxet i el Farró.pdf
# 2016_Vallcarca i els Penitents.pdf
# 2016_el Coll.pdf
# 2016_la Salut.pdf
# 2016_la Vila de Gràcia.pdf
# 2016_el Camp d'en Grassot i Gràcia Nova.pdf
# 2016_el Baix Guinardó.pdf
# 2016_Can Baró.pdf
# 2016_el Guinardó.pdf
# 2016_la Font d'en Fargues.pdf
# 2016_el Carmel.pdf
# 2016_la Teixonera.pdf
# 2016_Sant Genís dels Agudells.pdf
# 2016_Montbau.pdf
# 2016_la Vall d'Hebron.pdf
# 2016_la Clota.pdf
# 2016_Horta.pdf
# 2016_Vilapicina i la Torre Llobeta.pdf
# 2016_Porta.pdf
# 2016_el Turó de la Peira.pdf
# 2016_Can Peguera.pdf
# 2016_la Guineueta.pdf
# 2016_Canyelles.pdf
# 2016_les Roquetes.pdf
# 2016_Verdun.pdf
# 2016_la Prosperitat.pdf
# 2016_la Trinitat Nova.pdf
# 2016_Torre Baró.pdf
# 2016_Ciutat Meridiana.pdf
# 2016_Vallbona.pdf
# 2016_la Trinitat Vella.pdf
# 2016_Baró de Viver.pdf
# 2016_el Bon Pastor.pdf
# 2016_Sant Andreu.pdf
# 2016_la Sagrera.pdf
# 2016_el Congrés i els Indians.pdf
# 2016_Navas.pdf
# 2016_el Camp de l'Arpa del Clot.pdf
# 2016_el Clot.pdf
# 2016_el Parc i la Llacuna del Poblenou.pdf
# 2016_la Vila Olímpica del Poblenou.pdf
# 2016_el Poblenou.pdf
# 2016_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2016_el Besòs i el Maresme.pdf
# 2016_Provençals del Poblenou.pdf
# 2016_Sant Martí de Provençals.pdf
# 2016_la Verneda i la Pau.pdf
# 2011_el Raval.pdf
# 2011_el Barri Gòtic.pdf
# 2011_la Barceloneta.pdf
# 2011_Sant Pere, Santa Caterina i la Ribera.pdf
# 2011_el Fort Pienc.pdf
# 2011_la Sagrada Família.pdf
# 2011_la Dreta de l'Eixample.pdf
# 2011_l'Antiga Esquerra de l'Eixample.pdf
# 2011_la Nova Esquerra de l'Eixample.pdf
# 2011_Sant Antoni.pdf
# 2011_el Poble-sec.pdf
# 2011_la Marina del Prat Vermell.pdf
# 2011_la Marina de Port.pdf
# 2011_la Font de la Guatlla.pdf
# 2011_Hostafrancs.pdf
# 2011_la Bordeta.pdf
# 2011_Sants - Badal.pdf
# 2011_Sants.pdf
# 2011_les Corts.pdf
# 2011_la Maternitat i Sant Ramon.pdf
# 2011_Pedralbes.pdf
# 2011_Vallvidrera, el Tibidabo i les Planes.pdf
# 2011_Sarrià.pdf
# 2011_les Tres Torres.pdf
# 2011_Sant Gervasi - la Bonanova.pdf
# 2011_Sant Gervasi - Galvany.pdf
# 2011_el Putxet i el Farró.pdf
# 2011_Vallcarca i els Penitents.pdf
# 2011_el Coll.pdf
# 2011_la Salut.pdf
# 2011_la Vila de Gràcia.pdf
# 2011_el Camp d'en Grassot i Gràcia Nova.pdf
# 2011_el Baix Guinardó.pdf
# 2011_Can Baró.pdf
# 2011_el Guinardó.pdf
# 2011_la Font d'en Fargues.pdf
# 2011_el Carmel.pdf
# 2011_la Teixonera.pdf
# 2011_Sant Genís dels Agudells.pdf
# 2011_Montbau.pdf
# 2011_la Vall d'Hebron.pdf
# 2011_la Clota.pdf
# 2011_Horta.pdf
# 2011_Vilapicina i la Torre Llobeta.pdf
# 2011_Porta.pdf
# 2011_el Turó de la Peira.pdf
# 2011_Can Peguera.pdf
# 2011_la Guineueta.pdf
# 2011_Canyelles.pdf
# 2011_les Roquetes.pdf
# 2011_Verdun.pdf
# 2011_la Prosperitat.pdf
# 2011_la Trinitat Nova.pdf
# 2011_Torre Baró.pdf
# 2011_Ciutat Meridiana.pdf
# 2011_Vallbona.pdf
# 2011_la Trinitat Vella.pdf
# 2011_Baró de Viver.pdf
# 2011_el Bon Pastor.pdf
# 2011_Sant Andreu.pdf
# 2011_la Sagrera.pdf
# 2011_el Congrés i els Indians.pdf
# 2011_Navas.pdf
# 2011_el Camp de l'Arpa del Clot.pdf
# 2011_el Clot.pdf
# 2011_el Parc i la Llacuna del Poblenou.pdf
# 2011_la Vila Olímpica del Poblenou.pdf
# 2011_el Poblenou.pdf
# 2011_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2011_el Besòs i el Maresme.pdf
# 2011_Provençals del Poblenou.pdf
# 2011_Sant Martí de Provençals.pdf
# 2011_la Verneda i la Pau.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri1.pdf
# 2008_el Raval.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri2.pdf
# 2008_el Barri Gòtic.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri3.pdf
# 2008_la Barceloneta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri4.pdf
# 2008_Sant Pere, Santa Caterina i la Ribera.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri5.pdf
# 2008_el Fort Pienc.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri6.pdf
# 2008_la Sagrada Família.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri7.pdf
# 2008_la Dreta de l'Eixample.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri8.pdf
# 2008_l'Antiga Esquerra de l'Eixample.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri9.pdf
# 2008_la Nova Esquerra de l'Eixample.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri10.pdf
# 2008_Sant Antoni.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri11.pdf
# 2008_el Poble-sec.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri12.pdf
# 2008_la Marina del Prat Vermell.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri13.pdf
# 2008_la Marina de Port.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri14.pdf
# 2008_la Font de la Guatlla.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri15.pdf
# 2008_Hostafrancs.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri16.pdf
# 2008_la Bordeta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri17.pdf
# 2008_Sants - Badal.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri18.pdf
# 2008_Sants.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri19.pdf
# 2008_les Corts.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri20.pdf
# 2008_la Maternitat i Sant Ramon.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri21.pdf
# 2008_Pedralbes.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri22.pdf
# 2008_Vallvidrera, el Tibidabo i les Planes.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri23.pdf
# 2008_Sarrià.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri24.pdf
# 2008_les Tres Torres.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri25.pdf
# 2008_Sant Gervasi - la Bonanova.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri26.pdf
# 2008_Sant Gervasi - Galvany.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri27.pdf
# 2008_el Putxet i el Farró.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri28.pdf
# 2008_Vallcarca i els Penitents.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri29.pdf
# 2008_el Coll.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri30.pdf
# 2008_la Salut.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri31.pdf
# 2008_la Vila de Gràcia.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri32.pdf
# 2008_el Camp d'en Grassot i Gràcia Nova.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri33.pdf
# 2008_el Baix Guinardó.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri34.pdf
# 2008_Can Baró.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri35.pdf
# 2008_el Guinardó.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri36.pdf
# 2008_la Font d'en Fargues.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri37.pdf
# 2008_el Carmel.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri38.pdf
# 2008_la Teixonera.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri39.pdf
# 2008_Sant Genís dels Agudells.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri40.pdf
# 2008_Montbau.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri41.pdf
# 2008_la Vall d'Hebron.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri42.pdf
# 2008_la Clota.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri43.pdf
# 2008_Horta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri44.pdf
# 2008_Vilapicina i la Torre Llobeta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri45.pdf
# 2008_Porta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri46.pdf
# 2008_el Turó de la Peira.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri47.pdf
# 2008_Can Peguera.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri48.pdf
# 2008_la Guineueta.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri49.pdf
# 2008_Canyelles.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri50.pdf
# 2008_les Roquetes.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri51.pdf
# 2008_Verdun.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri52.pdf
# 2008_la Prosperitat.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri53.pdf
# 2008_la Trinitat Nova.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri54.pdf
# 2008_Torre Baró.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri55.pdf
# 2008_Ciutat Meridiana.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri56.pdf
# 2008_Vallbona.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri57.pdf
# 2008_la Trinitat Vella.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri58.pdf
# 2008_Baró de Viver.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri59.pdf
# 2008_el Bon Pastor.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri60.pdf
# 2008_Sant Andreu.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri61.pdf
# 2008_la Sagrera.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri62.pdf
# 2008_el Congrés i els Indians.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri63.pdf
# 2008_Navas.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri64.pdf
# 2008_el Camp de l'Arpa del Clot.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri65.pdf
# 2008_el Clot.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri66.pdf
# 2008_el Parc i la Llacuna del Poblenou.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri67.pdf
# 2008_la Vila Olímpica del Poblenou.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri68.pdf
# 2008_el Poblenou.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri69.pdf
# 2008_Diagonal Mar i el Front Marítim del Poblenou.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri70.pdf
# 2008_el Besòs i el Maresme.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri71.pdf
# 2008_Provençals del Poblenou.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri72.pdf
# 2008_Sant Martí de Provençals.pdf
# HTTP Error 404: Not Found
# https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Barris/Fitxes/a2008/barri73.pdf
# 2008_la Verneda i la Pau.pdf
# 2014_el Raval.pdf
# 2014_el Barri Gòtic.pdf
# 2014_la Barceloneta.pdf
# 2014_Sant Pere, Santa Caterina i la Ribera.pdf
# 2014_el Fort Pienc.pdf
# 2014_la Sagrada Família.pdf
# 2014_la Dreta de l'Eixample.pdf
# 2014_l'Antiga Esquerra de l'Eixample.pdf
# 2014_la Nova Esquerra de l'Eixample.pdf
# 2014_Sant Antoni.pdf
# 2014_el Poble-sec.pdf
# 2014_la Marina del Prat Vermell.pdf
# 2014_la Marina de Port.pdf
# 2014_la Font de la Guatlla.pdf
# 2014_Hostafrancs.pdf
# 2014_la Bordeta.pdf
# 2014_Sants - Badal.pdf
# 2014_Sants.pdf
# 2014_les Corts.pdf
# 2014_la Maternitat i Sant Ramon.pdf
# 2014_Pedralbes.pdf
# 2014_Vallvidrera, el Tibidabo i les Planes.pdf
# 2014_Sarrià.pdf
# 2014_les Tres Torres.pdf
# 2014_Sant Gervasi - la Bonanova.pdf
# 2014_Sant Gervasi - Galvany.pdf
# 2014_el Putxet i el Farró.pdf
# 2014_Vallcarca i els Penitents.pdf
# 2014_el Coll.pdf
# 2014_la Salut.pdf
# 2014_la Vila de Gràcia.pdf
# 2014_el Camp d'en Grassot i Gràcia Nova.pdf
# 2014_el Baix Guinardó.pdf
# 2014_Can Baró.pdf
# 2014_el Guinardó.pdf
# 2014_la Font d'en Fargues.pdf
# 2014_el Carmel.pdf
# 2014_la Teixonera.pdf
# 2014_Sant Genís dels Agudells.pdf
# 2014_Montbau.pdf
# 2014_la Vall d'Hebron.pdf
# 2014_la Clota.pdf
# 2014_Horta.pdf
# 2014_Vilapicina i la Torre Llobeta.pdf
# 2014_Porta.pdf
# 2014_el Turó de la Peira.pdf
# 2014_Can Peguera.pdf
# 2014_la Guineueta.pdf
# 2014_Canyelles.pdf
# 2014_les Roquetes.pdf
# 2014_Verdun.pdf
# 2014_la Prosperitat.pdf
# 2014_la Trinitat Nova.pdf
# 2014_Torre Baró.pdf
# 2014_Ciutat Meridiana.pdf
# 2014_Vallbona.pdf
# 2014_la Trinitat Vella.pdf
# 2014_Baró de Viver.pdf
# 2014_el Bon Pastor.pdf
# 2014_Sant Andreu.pdf
# 2014_la Sagrera.pdf
# 2014_el Congrés i els Indians.pdf
# 2014_Navas.pdf
# 2014_el Camp de l'Arpa del Clot.pdf
# 2014_el Clot.pdf
# 2014_el Parc i la Llacuna del Poblenou.pdf
# 2014_la Vila Olímpica del Poblenou.pdf
# 2014_el Poblenou.pdf
# 2014_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2014_el Besòs i el Maresme.pdf
# 2014_Provençals del Poblenou.pdf
# 2014_Sant Martí de Provençals.pdf
# 2014_la Verneda i la Pau.pdf
# 2019_el Raval.pdf
# 2019_el Barri Gòtic.pdf
# 2019_la Barceloneta.pdf
# 2019_Sant Pere, Santa Caterina i la Ribera.pdf
# 2019_el Fort Pienc.pdf
# 2019_la Sagrada Família.pdf
# 2019_la Dreta de l'Eixample.pdf
# 2019_l'Antiga Esquerra de l'Eixample.pdf
# 2019_la Nova Esquerra de l'Eixample.pdf
# 2019_Sant Antoni.pdf
# 2019_el Poble-sec.pdf
# 2019_la Marina del Prat Vermell.pdf
# 2019_la Marina de Port.pdf
# 2019_la Font de la Guatlla.pdf
# 2019_Hostafrancs.pdf
# 2019_la Bordeta.pdf
# 2019_Sants - Badal.pdf
# 2019_Sants.pdf
# 2019_les Corts.pdf
# 2019_la Maternitat i Sant Ramon.pdf
# 2019_Pedralbes.pdf
# 2019_Vallvidrera, el Tibidabo i les Planes.pdf
# 2019_Sarrià.pdf
# 2019_les Tres Torres.pdf
# 2019_Sant Gervasi - la Bonanova.pdf
# 2019_Sant Gervasi - Galvany.pdf
# 2019_el Putxet i el Farró.pdf
# 2019_Vallcarca i els Penitents.pdf
# 2019_el Coll.pdf
# 2019_la Salut.pdf
# 2019_la Vila de Gràcia.pdf
# 2019_el Camp d'en Grassot i Gràcia Nova.pdf
# 2019_el Baix Guinardó.pdf
# 2019_Can Baró.pdf
# 2019_el Guinardó.pdf
# 2019_la Font d'en Fargues.pdf
# 2019_el Carmel.pdf
# 2019_la Teixonera.pdf
# 2019_Sant Genís dels Agudells.pdf
# 2019_Montbau.pdf
# 2019_la Vall d'Hebron.pdf
# 2019_la Clota.pdf
# 2019_Horta.pdf
# 2019_Vilapicina i la Torre Llobeta.pdf
# 2019_Porta.pdf
# 2019_el Turó de la Peira.pdf
# 2019_Can Peguera.pdf
# 2019_la Guineueta.pdf
# 2019_Canyelles.pdf
# 2019_les Roquetes.pdf
# 2019_Verdun.pdf
# 2019_la Prosperitat.pdf
# 2019_la Trinitat Nova.pdf
# 2019_Torre Baró.pdf
# 2019_Ciutat Meridiana.pdf
# 2019_Vallbona.pdf
# 2019_la Trinitat Vella.pdf
# 2019_Baró de Viver.pdf
# 2019_el Bon Pastor.pdf
# 2019_Sant Andreu.pdf
# 2019_la Sagrera.pdf
# 2019_el Congrés i els Indians.pdf
# 2019_Navas.pdf
# 2019_el Camp de l'Arpa del Clot.pdf
# 2019_el Clot.pdf
# 2019_el Parc i la Llacuna del Poblenou.pdf
# 2019_la Vila Olímpica del Poblenou.pdf
# 2019_el Poblenou.pdf
# 2019_Diagonal Mar i el Front Marítim del Poblenou.pdf
# 2019_el Besòs i el Maresme.pdf
# 2019_Provençals del Poblenou.pdf
# 2019_Sant Martí de Provençals.pdf
# 2019_la Verneda i la Pau.pdf

# %% [markdown]
# We keep a list with the names of the files we have downloaded and also a list with the names of the files we have not been able to download.

# %%
#save the name of the files in a list with the path. here are the files that we already have downloaded
files = [os.path.join("pdf_files", file) for file in os.listdir("pdf_files")]

#print the number of files downloaded
print("Number of files downloaded: {}".format(len(files)))
# Out:
# Number of files downloaded: 803

# %%
#print the number of files with errors
print("Number of files with errors: {}".format(len(errors)))

# %% [markdown]
# _________

# %% [markdown]
# ## Extracting information from pdf files
#
# we already have the pdf files now what we are going to do is to extract the information from the files.
#
# To do this, the first thing we are going to do is to define a dictionary with the following keys
#
# + Barri = is the name of the neighborhood
# + Any = the year the information refers to
# + Població = is the population of the neighborhood for that year.
# + Superfície_(km2) = is the area in km2 of the neighborhood
# + Densitat_(hab/km2) = is the density of inhabitants per square kilometer.
# + Dones = Total number of women living in the neighborhood.
# + Homes = Total number of men living in the neighborhood.
# + edat_0_14 = percentage of the total population of the neighborhood aged 0 to 14 years old
# + edat_15_24 = percentage of the total population of the neighborhood aged 15 to 24 years old
# + edat_25_64 = percentage of the total population of the neighborhood aged 25 to 64 years old
# + edat_65_i_mes = percentage of the total population of the neighborhood over the age of 65
# + naixement_Barcelona = population of the neighborhood (in percentage) born in Barcelona
# + population of the neighborhood (in percentage) born outside of Barcelona but in the region of catalonia
# + naixement_Resta_Espanya = population of the neighborhood (in percentage) born in
# other parts of spain
# + naixement_Estranger = foreign-born population of the neighborhood (in percentage)
# + nacionalitat_Espanyols = percentage of the neighborhood's population with Spanish nationality
# + nacionalitat_Estrangers = percentage of the neighborhood's population with foreign nationality
# + Titulats_superiors = Percentage of the population with higher education in the neighborhood
# + Taxa_natalitat= neighborhood birth rate per 1000 inhabitants
# + mes_de_65_anys_viu_sola = percentage of the neighborhood population over 65 years old living alone
# + Index_de_sobreenvelliment =  index population >75 years/ population >65 years*100
# + Turismes = tourists in the neighborhood (persons) per 1,000 inhabitants
# + Motos = motorcycles (individuals) / 1,000 inhab.
# + Ciclomotors = Cyclomotors (physical persons) / 1,000 inhab.
# + aturats_registrats = Number of registered unemployed
# + Renda_familiar = Family income available per inhabitant

# %%
# create a empty dataframe with the columns we want.
# the columns are: "Any","Barri","Població","Superfície_(km2)",
# "Densitat_(hab/km2)","per_sexe_Dones","per_sexe_Homes","per_edat_(en %)_0-14",
# "per_edat_(en %)_15-24", "per_edat_(en %)_25-64", "per_edat_(en %)_65 i mes"
# "lloc de naixement_(en %)_Barcelona",""lloc de naixement_(en %)_Resta Catalunya"
#"lloc de naixement_(en %)_Resta Espanya", "lloc de naixement_(en %)_Estranger"
# per_nacionalitat_(en %)_Espanyols", "per_nacionalitat_(en %)_Estrangers"
#"%_Titulats superiors", "Taxa natalitat(1.000 hab)","més_de_65_anys_que_viu_sola_(%)"
#"Índex_de_sobreenvelliment", "Turismes_(persones físiques)_1.000 hab"
#"Motos_(persones_físiques)1.000_hab", "Ciclomotors_(persones físiques)1.000_hab"
#"Nombre_d'aturats_registrats", "Renda_familiar_disponible_per_habitant_(2017)"


columns = ["Barri","Any","Població", "Superfície_(km2)", "Densitat_(hab/km2)", "Dones", "Homes", "edat_0_14",
           "edat_15_24", "edat_25_64", "edat_65_i_mes", "naixement_Barcelona",
           "naixement_Resta_Catalunya", "naixement_Resta_Espanya", "naixement_Estranger",
           "nacionalitat_Espanyols", "nacionalitat_Estrangers", "Titulats_superiors",
           "Taxa_natalitat", "mes_de_65_anys_viu_sola", "Index_de_sobreenvelliment",
           "Turismes", "Motos",
           "Ciclomotors", "aturats_registrats", "Renda_familiar"]

# %%
#create a dictionary with the columns as keys and the values as empty lists
data_structure = {}
for column in columns:
    data_structure[column] = None

# %% [markdown]
# Now we are going to create a series of regular expressions that will allow us to extract the information from the pdf files.

# %%
# create a regex to get the data from the pdf files.

#patter to find the year(any) it is a  interger number after the string "SOCIOECONÒMICS "
any = re.compile(r"SOCIOECONÒMICS\s+(\d+)")

# pattert to find the poblation it is a number with 1 or more digits and a comma or a dot and 1 or more digits after the comma or dot after the word "Població"
poblacio = re.compile(r'Població\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Superfície (km2) "
superficie = re.compile(r'Superfície\s\(km2\)\s+(\d+[\.,]\d+|\d+)')


# pattert to find a number with 1 or more digits after the word "Densitat (hab/km2) "
densitat = re.compile(r'Densitat\s\(hab/km2\)\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Dones" or a interger after the word "Dones"
dones = re.compile(r'Dones\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Homes", or a interger after the word "Homes"
homes = re.compile(r'Homes\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after 0-14
edat_0_14 = re.compile(r'[0].[1][4]\s+(\d+[\.,]\d+|\d+)')



# pattert to find a number with 1 or more digits after 15"-"24, or a interger after 15"-"24" "
edat_15_24 = re.compile(r'[1][5].[2][4]\s+(\d+[\.,]\d+|\d+)')


# pattert to find a number with 1 or more digits after the word "25-64"
edat_25_64 = re.compile(r'[2][5].[6][4]\s+(\d+[\.,]\d+|\d+)')


# pattert to find a number with 1 or more digits after the word "65 i mes " o 65 i mes"
edat_65_i_mes = re.compile(r'[6][5]\s[i]\s[m][e][s]\s+(\d+[\.,]\d+|\d+)')


# pattert to find a number with 1 or more digits after the word "Barcelona"
naixement_Barcelona = re.compile(r'Barcelona\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Resta Catalunya"
naixement_Resta_Catalunya = re.compile(r'Resta\sCatalunya\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Resta Espanya"
naixement_Resta_Espanya = re.compile(r'ta\sEspanya\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Estranger"
naixement_Estranger = re.compile(r'Estranger\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Espanyols"
nacionalitat_Espanyols = re.compile(r'Espanyols\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Estrangers"
nacionalitat_Estrangers = re.compile(r'Estrangers\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "CFGS (1)"
Titulats_superiors = re.compile(r'CFGS\s\(1\)\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Taxa natalitat / 1.000 hab."
Taxa_natalitat = re.compile(r'Taxa natalitat / 1.000 hab.\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word "Població de més de 65 anys que viu sola (%) (2)"
mes_de_65_anys_viu_sola = re.compile(r'Població de més de 65 anys que viu sola \(%\) \(2\)\s+(\d+[\.,]\d+|\d+)')

# pattert to find a number with 1 or more digits after the word Index de sobreenvelliment (?)"
Index_de_sobreenvelliment = re.compile(r"Índex de sobreenvelliment\s+\(\d+\)\s+(\d+[\.,]\d+|\d+)")

# pattert to find a number with 1 or more digits after the word "Turismes (persones físiques) / 1.000 hab (4)"
Turismes = re.compile(r"Turismes \(persones físiques\)\s\/\s1\.000\shab\s\(\d\)\s+(\d+[\.,]\d+|\d+)")

# pattert to find a number with 1 or more digits after the word "Motos (persones físiques) / 1.000 hab (4)"
Motos = re.compile(r"(Motos\s\(persones\sfísiques\)\s\/\s1\.000\shab\s\(\d\)\s|Motos\s\(persones\sfísiques\)\s\/\s1\.000\shab\s)+(\d+[\.,]\d+|\d+)")

# pattert to find a number with 1 or more digits after the word "Ciclomotors (persones físiques) / 1.000 hab (4)"

Ciclomotors = re.compile(r'Ciclomotors \(persones físiques\)\s\/\s1\.000\shab\s\(\d\)\s+(\d+[\.,]\d+|\d+)')

# pattert to find any interger after the word "(5)"
aturats_registrats = re.compile(r"Nombre d'aturats registrats\s\(\d\)\s+(\d+[\.,]\d+|\d+)")

# pattert to find a number with 1 or more digits after the word "(2017)"
Renda_familiar = re.compile(r"Renda\sfamiliar\sdisponible\sper\shabitant\s\(\d{4}\)\s+(\d+[\.,]\d+|\d+)")

# %% [markdown]
# once the regular expressions have been defined, we will extract the information from the pdfs and save what we are interested in

# %%
# here we are going to create a list of all the patterns. This will be useful later
# also we are going to use pdfplumber to extract the text from the pdf
values = []


for file in files:


    data = data_structure
    data["Barri"] = file[:-4][15:]
    # print(file[:-4][15:])

    with pdfplumber.open(file) as pdf:
        # check if the pdf has 2 pages
        if len(pdf.pages) == 2:
        
            page = pdf.pages[1]
            text = page.extract_text()
            for i in text.split('\n'):
                
                if any.search(i):
                    # finding the "Any" pattern that matches the text and adding it to the dictionary
                    data['Any'] = any.search(i).group(1)
                    # print(any.search(i).group(1))
                    continue

                    # find the "Població" pattern that matches the text and adding it to the dictionary
                if poblacio.search(i):
                    data["Població"] = poblacio.search(i).group(1)
                    # print(poblacio.search(i).group(1))
                
                    continue

                    # find the "superfície" pattern that matches the text and adding it to the dictionary
                if superficie.search(i):
                
                    data['Superfície_(km2)'] = superficie.search(i).group(1)
                    # print(superficie.search(i).group(1))

                    continue

                    # find the "densitat" pattern that matches the text and adding it to the dictionary
                if densitat.search(i):
                    
                    data["Densitat_(hab/km2)"] = densitat.search(i).group(1)
                    # print(densitat.search(i).group(1))

                    continue

                    # find the Dones pattern that matches the text and adding it to the dictionary
                if dones.search(i):
                    
                    data["Dones"]= dones.search(i).group(1)
                    # print(dones.search(i).group(1))

                    continue

                    # find the Homes pattern that matches the text and adding it to the dictionary
                if homes.search(i):
                        # print(homes.search(i).group(1))
                        data["Homes"] = homes.search(i).group(1)
                        continue

                    # find the edat_0_14 pattern that matches the text and adding it to the dictionary
                if edat_0_14.search(i):
                        # print(edat_0_14.search(i).group(1))
                        data["edat_0_14"] = edat_0_14.search(i).group(1)
                        continue

                # find the edat_15_64 pattern that matches the text and adding it to the dictionary
                if edat_15_24.search(i):
                        # print(edat_15_24.search(i).group(1))
                        data["edat_15_24"] = edat_15_24.search(i).group(1)
                        continue
                        #find the edat_25_64 pattern that matches the text and adding it to the dictionary
                if edat_25_64.search(i):
                        # print(edat_25_64.search(i).group(1))
                        data["edat_25_64"] = edat_25_64.search(i).group(1)
                        continue

                    # find the pattern  edat_65_i_mes that matches the text and adding it to the dictionary
                if edat_65_i_mes.search(i):
                        # print(edat_65_i_mes.search(i).group(1))
                        data ["edat_65_i_mes"]= edat_65_i_mes.search(i).group(1)
                        continue


                    # find the naixement_Barcelona pattern that matches the text and adding it to the dictionary
                if naixement_Barcelona.search(i):
                        # print(naixement_Barcelona.search(i).group(1))
                        data["naixement_Barcelona"] = naixement_Barcelona.search(i).group(1)
                        continue

                    # find the naixement_Resta_Catalunya pattern that matches the text and adding it to the dictionary
                if naixement_Resta_Catalunya.search(i):
                        # print(naixement_Resta_Catalunya.search(i).group(1))
                        data["naixement_Resta_Catalunya"]= naixement_Resta_Catalunya.search(i).group(1)
                        continue

                    # find the naixement_Resta_Espanya pattern that matches the text and adding it to the dictionary
                if naixement_Resta_Espanya.search(i):
                        # print(naixement_Resta_Espanya.search(i).group(1))
                        data["naixement_Resta_Espanya"]= naixement_Resta_Espanya.search(i).group(1)
                        continue

                    # find the naixement_Extranger pattern that matches the text and adding it to the dictionary
                if naixement_Estranger.search(i):
                        # print(naixement_Estranger.search(i).group(1))
                        data["naixement_Estranger"] = naixement_Estranger.search(i).group(1)
                        continue

                    # find the nacionalitat_Espanyols pattern that matches the text and adding it to the dictionary
                if nacionalitat_Espanyols.search(i):
                        # print(nacionalitat_Espanyols.search(i).group(1))
                        data["nacionalitat_Espanyols"] = nacionalitat_Espanyols.search(i).group(1)
                        continue

                    # find the nacionalitat_Estrangers

                if nacionalitat_Estrangers.search(i):
                        # print(nacionalitat_Estrangers.search(i).group(1))
                        data["nacionalitat_Estrangers"] = nacionalitat_Estrangers.search(i).group(1)
                        continue

                    # find the Titulats_superiors pattern that matches the text and adding it to the dictionary
                if Titulats_superiors.search(i):
                        # print(Titulats_superiors.search(i).group(1))
                        data["Titulats_superiors"] = Titulats_superiors.search(i).group(1)
                        continue

                    # find the Taxa_natalitat pattern that matches the text and adding it to the dictionary
                if Taxa_natalitat.search(i):
                        # print(Taxa_natalitat.search(i).group(1))
                        data["Taxa_natalitat"] = Taxa_natalitat.search(i).group(1)
                        continue

                    # find the mes_de_65_anys_viu_sola pattern that matches the text and adding it to the dictionary
                if mes_de_65_anys_viu_sola.search(i):
                        # print(mes_de_65_anys_viu_sola.search(i).group(1))
                        data["mes_de_65_anys_viu_sola"] = mes_de_65_anys_viu_sola.search(i).group(1)
                        continue

                    # find the Index_de_sobreenvelliment and get the number
                if Index_de_sobreenvelliment.search(i):
                        # print(Index_de_sobreenvelliment.search(i).group(1))
                        data["Index_de_sobreenvelliment"] = Index_de_sobreenvelliment.search(i).group(1)
                        continue

                    # find the Turisme pattern that matches the text and adding it to the dictionary
                if Turismes.search(i):
                        # print(Turismes.search(i).group(1))
                        data["Turismes"] = Turismes.search(i).group(1)
                        continue

                    # find the Motos pattern that matches the text and adding it to the dictionary

                if Motos.search(i):
                    # print(Motos.search(i).group(1))
                    data["Motos"] = Motos.search(i).group(2)
                    continue

                    #find the Ciclomotors pattern that matches the text and adding it to the dictionary

                if Ciclomotors.search(i):
                    # print(Ciclomotors.search(i).group(1))
                    data["Ciclomotors"] = Ciclomotors.search(i).group(1)
                    continue
                
                
                    # find the aturats_registrats pattern that matches the text and adding it to the dictionary
                if aturats_registrats.search(i):
                    # print(aturats_registrats.search(i).group(1))
                    data["aturats_registrats"] = aturats_registrats.search(i).group(1)
                    continue   

                    #find the renta familiar pattern that matches the text and adding it to the dictionary
                if Renda_familiar.search(i):
                    # print(Renda_familiar.search(i).group(1))
                    data["Renda_familiar"] = Renda_familiar.search(i).group(1)
                    continue
        else:
            print(file + " this .pdf file no have the same pages as the others")     
    values.append(data.copy())
#
# Out:
# pdf_files/2015_el Putxet i el Farró.pdf this .pdf file no have the same pages as the others

# %% [markdown]
# we create a dataframe with the extracted information

# %%
data_barris = pd.DataFrame(values)
data_barris
# Out:
#                                      Barri   Any Població Superfície_(km2)  \
# 0    Sant Pere, Santa Caterina i la Ribera  2012   22.873              1,1
# 1                                  el Clot  2012   27.201              0,7
# 2                    el Putxet i el Farró  2016   27.201              0,8
# 3                         la Trinitat Nova  2016   27.201              0,6
# 4                              Torre Baró  2018    2.931              1,7
# ..                                     ...   ...      ...              ...
# 798                     la Vila de Gràcia  2013   52.586              1,3
# 799                            el Poblenou  2014   52.586              1,5
# 800          Vilapicina i la Torre Llobeta  2013   25.527              0,6
# 801                         la Barceloneta  2017   25.527              1,3
# 802                                  Porta  2018   26.557              0,8
#
#     Densitat_(hab/km2)   Dones   Homes edat_0_14 edat_15_24 edat_25_64  ...  \
# 0               20.527  11.479  11.394       9,7        8,4       66,0  ...
# 1               39.085  14.079  13.122      13,1        9,2       60,4  ...
# 2               34.996  16.176  13.441      14,3       10,0       54,7  ...
# 3               12.982   3.813   3.458      14,6       10,2       56,5  ...
# 4                1.653   1.457   1.474      17,9       12,5       56,7  ...
# ..                 ...     ...     ...       ...        ...        ...  ...
# 798             39.657  28.233  24.353      10,2        7,5       62,7  ...
# 799             21.634  17.182  16.243      15,9        7,2       60,0  ...
# 800             45.021  13.798  11.729      11,9        8,6       55,2  ...
# 801             11.335   7.489   7.404       8,2        8,9       65,0  ...
# 802             30.433  14.214  12.343      12,3        8,9       55,2  ...
#
#     nacionalitat_Estrangers Titulats_superiors Taxa_natalitat  \
# 0                      38,5               33,7            9,3
# 1                      14,4               21,6            9,3
# 2                      13,0               48,9            9,3
# 3                      18,7                7,5            9,3
# 4                      18,7                8,2            9,7
# ..                      ...                ...            ...
# 798                    17,6               10,3            8,5
# 799                    16,6               29,3            8,5
# 800                    12,2               18,7            8,5
# 801                    36,0               28,6            8,5
# 802                    20,2               17,9            7,6
#
#     mes_de_65_anys_viu_sola Index_de_sobreenvelliment Turismes  Motos  \
# 0                      30,4                      54,1    237,8   97,9
# 1                      30,4                      54,1    237,8   95,5
# 2                      30,4                      54,1    237,8  213,7
# 3                      30,4                      54,1    237,8   62,5
# 4                      21,8                      46,2    290,7   77,8
# ..                      ...                       ...      ...    ...
# 798                    19,6                      45,9    379,9  128,5
# 799                    19,6                      45,9    379,9   94,2
# 800                    19,6                      45,9    379,9   88,5
# 801                    19,6                      45,9    379,9  110,3
# 802                    25,2                      57,0    244,1   76,6
#
#     Ciclomotors aturats_registrats Renda_familiar
# 0          24,5                613           89,1
# 1          24,5                613           81,1
# 2          24,5                613          141,0
# 3          24,5                613           35,6
# 4          24,5                169           46,5
# ..          ...                ...            ...
# 798        28,1                 93          146,6
# 799        28,1                 93           89,6
# 800        28,1                 93           71,7
# 801        28,1                 93           84,8
# 802        28,1              1.196           64,4
#
# [803 rows x 26 columns]

# %%
#show the info of the dataframe
data_barris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Barri                      803 non-null    object
#  1   Any                        803 non-null    object
#  2   Població                   803 non-null    object
#  3   Superfície_(km2)           803 non-null    object
#  4   Densitat_(hab/km2)         803 non-null    object
#  5   Dones                      803 non-null    object
#  6   Homes                      803 non-null    object
#  7   edat_0_14                  803 non-null    object
#  8   edat_15_24                 803 non-null    object
#  9   edat_25_64                 803 non-null    object
#  10  edat_65_i_mes              803 non-null    object
#  11  naixement_Barcelona        803 non-null    object
#  12  naixement_Resta_Catalunya  803 non-null    object
#  13  naixement_Resta_Espanya    803 non-null    object
#  14  naixement_Estranger        803 non-null    object
#  15  nacionalitat_Espanyols     803 non-null    object
#  16  nacionalitat_Estrangers    803 non-null    object
#  17  Titulats_superiors         803 non-null    object
#  18  Taxa_natalitat             803 non-null    object
#  19  mes_de_65_anys_viu_sola    803 non-null    object
#  20  Index_de_sobreenvelliment  803 non-null    object
#  21  Turismes                   803 non-null    object
#  22  Motos                      803 non-null    object
#  23  Ciclomotors                803 non-null    object
#  24  aturats_registrats         803 non-null    object
#  25  Renda_familiar             803 non-null    object
# dtypes: object(26)
# memory usage: 163.2+ KB

# %% [markdown]
# now we are going to clean up the data

# %%
#replace "," with "." in the dataframe
data_barris = data_barris.replace(',','.', regex=True)

# %%
data_barris
# Out:
#                                      Barri   Any Població Superfície_(km2)  \
# 0    Sant Pere. Santa Caterina i la Ribera  2012   22.873              1.1
# 1                                  el Clot  2012   27.201              0.7
# 2                    el Putxet i el Farró  2016   27.201              0.8
# 3                         la Trinitat Nova  2016   27.201              0.6
# 4                              Torre Baró  2018    2.931              1.7
# ..                                     ...   ...      ...              ...
# 798                     la Vila de Gràcia  2013   52.586              1.3
# 799                            el Poblenou  2014   52.586              1.5
# 800          Vilapicina i la Torre Llobeta  2013   25.527              0.6
# 801                         la Barceloneta  2017   25.527              1.3
# 802                                  Porta  2018   26.557              0.8
#
#     Densitat_(hab/km2)   Dones   Homes edat_0_14 edat_15_24 edat_25_64  ...  \
# 0               20.527  11.479  11.394       9.7        8.4       66.0  ...
# 1               39.085  14.079  13.122      13.1        9.2       60.4  ...
# 2               34.996  16.176  13.441      14.3       10.0       54.7  ...
# 3               12.982   3.813   3.458      14.6       10.2       56.5  ...
# 4                1.653   1.457   1.474      17.9       12.5       56.7  ...
# ..                 ...     ...     ...       ...        ...        ...  ...
# 798             39.657  28.233  24.353      10.2        7.5       62.7  ...
# 799             21.634  17.182  16.243      15.9        7.2       60.0  ...
# 800             45.021  13.798  11.729      11.9        8.6       55.2  ...
# 801             11.335   7.489   7.404       8.2        8.9       65.0  ...
# 802             30.433  14.214  12.343      12.3        8.9       55.2  ...
#
#     nacionalitat_Estrangers Titulats_superiors Taxa_natalitat  \
# 0                      38.5               33.7            9.3
# 1                      14.4               21.6            9.3
# 2                      13.0               48.9            9.3
# 3                      18.7                7.5            9.3
# 4                      18.7                8.2            9.7
# ..                      ...                ...            ...
# 798                    17.6               10.3            8.5
# 799                    16.6               29.3            8.5
# 800                    12.2               18.7            8.5
# 801                    36.0               28.6            8.5
# 802                    20.2               17.9            7.6
#
#     mes_de_65_anys_viu_sola Index_de_sobreenvelliment Turismes  Motos  \
# 0                      30.4                      54.1    237.8   97.9
# 1                      30.4                      54.1    237.8   95.5
# 2                      30.4                      54.1    237.8  213.7
# 3                      30.4                      54.1    237.8   62.5
# 4                      21.8                      46.2    290.7   77.8
# ..                      ...                       ...      ...    ...
# 798                    19.6                      45.9    379.9  128.5
# 799                    19.6                      45.9    379.9   94.2
# 800                    19.6                      45.9    379.9   88.5
# 801                    19.6                      45.9    379.9  110.3
# 802                    25.2                      57.0    244.1   76.6
#
#     Ciclomotors aturats_registrats Renda_familiar
# 0          24.5                613           89.1
# 1          24.5                613           81.1
# 2          24.5                613          141.0
# 3          24.5                613           35.6
# 4          24.5                169           46.5
# ..          ...                ...            ...
# 798        28.1                 93          146.6
# 799        28.1                 93           89.6
# 800        28.1                 93           71.7
# 801        28.1                 93           84.8
# 802        28.1              1.196           64.4
#
# [803 rows x 26 columns]

# %%
#change the type of the columns to int 
to_change = ["Any"]
data_barris[to_change] = data_barris[to_change].astype(int)

#change Població: extract "." and transform to int
data_barris["Població"] = data_barris["Població"].str.replace(".","")
data_barris["Població"] = data_barris["Població"].astype(int)

# %%
# safe the dataframe to a csv file as a backup
data_barris.to_csv("data_barris.csv", index=False)

# %%
#read the csv file
data_barris = pd.read_csv("data_barris.csv")
